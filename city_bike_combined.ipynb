# %%
import pandas as pd
import glob
# from os import listdir

# %%
path = "../Tableau_HW/Resources/"
all_files = glob.glob(path + "/*.csv")

# %%
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

data = pd.concat(li, axis=0, ignore_index=True)
data
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                156  2020-10-01 00:02:40.2600  2020-10-01 00:05:17.0140
# 1                143  2020-10-01 00:02:53.5020  2020-10-01 00:05:16.9650
# 2                305  2020-10-01 00:04:31.3160  2020-10-01 00:09:36.3840
# 3               1097  2020-10-01 00:05:18.3680  2020-10-01 00:23:36.1240
# 4                277  2020-10-01 00:09:17.5990  2020-10-01 00:13:55.5150
# ...              ...                       ...                       ...
# 354353           270  2020-10-13 15:05:35.0860  2020-10-13 15:10:05.3430
# 354354           400  2020-10-13 15:09:03.4890  2020-10-13 15:15:43.9750
# 354355           206  2020-10-13 15:11:34.3500  2020-10-13 15:15:00.5030
# 354356           216  2020-10-13 15:11:49.1510  2020-10-13 15:15:25.6930
# 354357           418  2020-10-13 15:12:31.7920  2020-10-13 15:19:30.5280
#
#         start station id start station name  start station latitude  \
# 0                   3186      Grove St PATH               40.719586
# 1                   3186      Grove St PATH               40.719586
# 2                   3273       Manila & 1st               40.721651
# 3                   3199       Newport Pkwy               40.728745
# 4                   3199       Newport Pkwy               40.728745
# ...                  ...                ...                     ...
# 354353              3207        Oakland Ave               40.737604
# 354354              3209       Brunswick St               40.724176
# 354355              3195            Sip Ave               40.730897
# 354356              3195            Sip Ave               40.730897
# 354357              3267       Morris Canal               40.712419
#
#         start station longitude  end station id       end station name  \
# 0                    -74.043117            3270        Jersey & 6th St
# 1                    -74.043117            3270        Jersey & 6th St
# 2                    -74.042884            3269        Brunswick & 6th
# 3                    -74.032108            3281    Leonard Gordon Park
# 4                    -74.032108            3638          Washington St
# ...                         ...             ...                    ...
# 354353               -74.052478            3640         Journal Square
# 354354               -74.050656            3209           Brunswick St
# 354355               -74.063913            3194        McGinley Square
# 354356               -74.063913            3225  Baldwin at Montgomery
# 354357               -74.038526            3186          Grove St PATH
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 0                  40.725289             -74.045572   42293  Subscriber
# 1                  40.725289             -74.045572   44740  Subscriber
# 2                  40.726012             -74.050389   41369  Subscriber
# 3                  40.745910             -74.057271   42285    Customer
# 4                  40.724294             -74.035483   45231  Subscriber
# ...                      ...                    ...     ...         ...
# 354353             40.733670             -74.062500   44744  Subscriber
# 354354             40.724176             -74.050656   45345  Subscriber
# 354355             40.725340             -74.067622   47019  Subscriber
# 354356             40.723659             -74.064194   42191  Subscriber
# 354357             40.719586             -74.043117   47255  Subscriber
#
#         birth year  gender
# 0             1996       1
# 1             1998       1
# 2             1988       2
# 3             2001       1
# 4             1965       1
# ...            ...     ...
# 354353        1963       2
# 354354        1984       1
# 354355        1993       1
# 354356        1966       1
# 354357        1991       1
#
# [354358 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354358 entries, 0 to 354357
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             354358 non-null  int64
#  1   starttime                354358 non-null  object
#  2   stoptime                 354358 non-null  object
#  3   start station id         354358 non-null  int64
#  4   start station name       354358 non-null  object
#  5   start station latitude   354358 non-null  float64
#  6   start station longitude  354358 non-null  float64
#  7   end station id           354358 non-null  int64
#  8   end station name         354358 non-null  object
#  9   end station latitude     354358 non-null  float64
#  10  end station longitude    354358 non-null  float64
#  11  bikeid                   354358 non-null  int64
#  12  usertype                 354358 non-null  object
#  13  birth year               354358 non-null  int64
#  14  gender                   354358 non-null  int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 40.6+ MB

# %%
data.to_csv("citi_bike_combined.csv", index=False)
